# %%
from qam import *

# %%
code = np.array((-2-2j, -2-1j,-2+2j,-2+1j,-1-2j,-1-1j,-1+2j,-1+1j,+2-2j,+2-1j,+2+2j+2+1j,1-2j,+1-1j,1+2j,1+1j))/2

np.random.seed(seed=1)
rbits = np.int16(rand(6,1)*15)
prefix = np.array([[0],[2],[10],[8]])#, [0],[2],[10],[8]])
bits = np.int16(rand(26,1)*15)

Nbits = len(rbits) + len(prefix) + len(bits)  # number of bits
print "Generating %d random bits"%(Nbits)
bits = np.array(rbits.tolist() + prefix.tolist() + bits.tolist())
# Out:
# Generating 36 random bits

# %% [markdown]
# Modulate

# %%
QAM, M, t, M_prefix, t_prefix = mod_QAM16(bits, prefix, f0=1800, tbw=4, fs=48000, baud=300, shaped=False, plot=False)

# %% [markdown]
# Demodulate

# %%
r,i = demod_QAM16(QAM, t, f0=1800, fs=48000)

# %% [markdown]
# Detect Sync

# %%
corr_index = detect_sync(r, i, M_prefix, len(prefix))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-8a830221b871> in <module>()
# ----> 1 corr_index = detect_sync(r, i, M_prefix, len(prefix))
#
# /home/vikram/work/ham_qam/qam.py in detect_sync(r, i, sync, sync_bits)
#     123     corr_r = abs(signal.correlate(r.ravel(), sync.real.ravel(),"same"))
#     124     corr_i = abs(signal.correlate(i.ravel(), sync.imag.ravel(),"same"))
# --> 125     corr_index = np.argmax(corr_r)-sync_bits/2*Ns
#     126     print np.max(np.abs(corr_r))
#     127     print np.max(np.abs(corr_i))
#
# NameError: global name 'Ns' is not defined

# %% [markdown]
# Decode

# %%
decode_symbols(r, i, corr_index, M.real.ravel(), M.imag.ravel())
